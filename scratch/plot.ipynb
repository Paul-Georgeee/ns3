# %% [markdown]
# Connected to Python 3.10.12

# %%
import matplotlib.pyplot as plt

# %%
path = "/home/ybxiao/cc/ns-3-dev/results/100Mbps-40ms/TcpBbr/0.25-bufferSize/0.0-lossRate/2024-03-07-03-48-47/cwnd.dat"
# 读取数据
data = []
with open(path, 'r') as f:
    for line in f.readlines():
        t = float(line.split()[0])
        cwnd = float(line.split()[1])
        data.append([t, cwnd])

# 删掉data中第一列数据大于50的行
data = [row for row in data if row[0] <= 40]

x = [row[0] for row in data]

# 提取第二列作为纵坐标
y = [row[1] for row in data]

plt.figure(figsize=(18, 8))

# 绘制折线图
plt.plot(x, y)

# 设置图表标题和坐标轴标签
plt.title('Line Plot')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')

# 显示图表
plt.show()

# %%
path = "/home/ybxiao/cc/ns-3-dev/results/100Mbps-40ms/TcpBbr/0.25-bufferSize/0.0-lossRate/2024-03-07-03-48-47/pacingRate.dat"
# 读取数据
data = []
with open(path, 'r') as f:
    for line in f.readlines():
        t = float(line.split()[0])
        bw = float(line.split()[1].rstrip("Mbps"))
        data.append([t, bw])

# 删掉data中第一列数据大于50的行
data = [row for row in data if row[0] <= 20]

x = [row[0] for row in data]

# 提取第二列作为纵坐标
y = [row[1] for row in data]

plt.figure(figsize=(18, 8))

# 绘制折线图
plt.plot(x, y)

# 设置图表标题和坐标轴标签
plt.title('Line Plot')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')

# 显示图表
plt.show()

# %%
path = "/home/ybxiao/cc/ns-3-dev/results/100Mbps-40ms/TcpBbr/0.25-bufferSize/0.0-lossRate/2024-03-07-03-48-47/throughput.dat"
# 读取数据
data = []
cur = 0.0
with open(path, 'r') as f:
    for line in f.readlines():
        t = float(line.split()[0])
        loss = float(line.split()[9])

        data.append([t, loss - cur])
        cur = loss

# 删掉data中第一列数据大于50的行
data = [row for row in data if row[0] <= 20]

x = [row[0] for row in data]

# 提取第二列作为纵坐标
y = [row[1] for row in data]

plt.figure(figsize=(18, 8))

# 绘制折线图
plt.plot(x, y)

# 设置图表标题和坐标轴标签
plt.title('Line Plot')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')

# 显示图表
plt.show()

# %%
def two_y_axis_plot(x1, y1, x2, y2, y1_label, y2_label):
    fig, ax1 = plt.subplots(figsize=(10, 4))

    ax1.plot(x1, y1, 'g-', label=y1_label)
    ax1.set_xlabel('time (s)')
    ax1.set_ylabel(y1_label, color='g')
    ax1.tick_params('y', colors='g')

    ax2 = ax1.twinx()
    ax2.plot(x2, y2, 'b-', label=y2_label)
    ax2.set_ylabel(y2_label, color='b')
    ax2.tick_params('y', colors='b')

    
    lines1, labels1 = ax1.get_legend_handles_labels()
    lines2, labels2 = ax2.get_legend_handles_labels()
    lines = lines1 + lines2
    labels = labels1 + labels2
    ax1.legend(lines, labels, loc='upper left')

    plt.show()

# %%
cwndData = []
path = "/home/ybxiao/cc/ns-3-dev/results/100Mbps-40ms/OBBR/0.25-bufferSize/0.0-lossRate/OBBRU-0.5/2024-03-20-11-56-05/cwnd.dat"
# 读取数据
with open(path, 'r') as f:
    for line in f.readlines():
        t = float(line.split()[0])
        gain = float(line.split()[1])
        cwndData.append([t, gain])
cwndData = [row for row in cwndData if  10 <= row[0] and row[0] <= 20]

path = "/home/ybxiao/cc/ns-3-dev/results/100Mbps-40ms/OBBR/0.25-bufferSize/0.0-lossRate/OBBRU-0.5/2024-03-20-11-56-05/pacingGain.dat"
pacingGainData = []
with open(path, 'r') as f:
    for line in f.readlines():
        t = float(line.split()[0])
        gain = float(line.split()[6])
        pacingGainData.append([t, gain])
pacingGainData = [row for row in pacingGainData if  10 <= row[0] and row[0] <= 20]



x1 = [row[0] for row in cwndData]

# 提取第二列作为第一条线的纵坐标
y1 = [row[1] for row in cwndData]

x2 = [row[0] for row in pacingGainData]
# 提取第二列作为第二条线的纵坐标
y2 = [row[1] for row in pacingGainData]

two_y_axis_plot(x1, y1, x2, y2, 'cwnd', 'pacingGain')

# %%
path = "/home/ybxiao/cc/ns-3-dev/results/100Mbps-40ms/OBBR/0.25-bufferSize/0.0-lossRate/OBBRU-0.5/2024-03-07-03-48-47/pacingGain.dat"
pacingGainData = []
with open(path, 'r') as f:
    for line in f.readlines():
        t = float(line.split()[0])
        gain = float(line.split()[6])
        pacingGainData.append([t, gain])
pacingGainData = [row for row in pacingGainData if  10 <= row[0] and row[0] <= 20]

#cwnd data
path = "/home/ybxiao/cc/ns-3-dev/results/100Mbps-40ms/OBBR/0.25-bufferSize/0.0-lossRate/OBBRU-0.5/2024-03-07-03-48-47/cwnd.dat"
cwndData = []
with open(path, 'r') as f:
    for line in f.readlines():
        t = float(line.split()[0])
        cwnd = float(line.split()[1])
        cwndData.append([t, cwnd])

cwndData = [row for row in cwndData if  10 <= row[0] and row[0] <= 20]



x1 = [row[0] for row in pacingGainData]

# 提取第二列作为第一条线的纵坐标
y1 = [row[1] for row in pacingGainData]

x2 = [row[0] for row in cwndData]
# 提取第二列作为第二条线的纵坐标
y2 = [row[1] for row in cwndData]

# 创建画布
fig, ax1 = plt.subplots(figsize=(10, 4))

ax1.plot(x1, y1, 'g-', label='pacingGain')
ax1.set_xlabel('Time (s)')
ax1.set_ylabel('pacing gain', color='g')
ax1.tick_params('y', colors='g')

# 创建第二个y轴
ax2 = ax1.twinx()
ax2.plot(x2, y2, 'b-', label='cwnd')
ax2.set_ylabel('cwnd (segment)', color='b')
ax2.tick_params('y', colors='b')

lines1, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
lines = lines1 + lines2
labels = labels1 + labels2
ax1.legend(lines, labels, loc='upper left')

plt.show()

# %%
path = "/home/ybxiao/test.txt"
startTime = -1
pacingGainData = []
resendData = []
bwData = []
sampleBwData = []

with open(path, 'r') as f:
    for line in f.readlines():
        if(line[0:3] == "re:"):
            cols = line[3:].split(',') 
            t = float(cols[0])
            resent = float(cols[1])
            bw = float(cols[2])
            if(startTime == -1):
                startTime = t
            t = t - startTime
            resendData.append([t, resent])
            bwData.append([t, bw])

        else:
            cols = line[3:].split(',')
            t = float(cols[0])
            sample = float(cols[3])
            if(startTime == -1):
                startTime = t
            t = t - startTime
            sampleBwData.append([t, sample])
    
       
resendData = [row for row in resendData if  30000 <= row[0] and row[0] <= 38000]
bwData = [row for row in bwData if 30000 <= row[0] and row[0] <= 38000]


x1 = [row[0] for row in bwData]

# 提取第二列作为第一条线的纵坐标
y1 = [row[1] for row in bwData]

x2 = [row[0] for row in sampleBwData]
# 提取第二列作为第二条线的纵坐标
y2 = [row[1] for row in sampleBwData]

# 创建画布
fig, ax1 = plt.subplots(figsize=(10, 5))

ax1.plot(x1, y1, 'g-', label='bwData')
ax1.set_xlabel('Time (s)')
ax1.set_ylabel('bwData', color='g')
ax1.tick_params('y', colors='g')
ax1.axhline(y=12500000, color='r', linestyle='--', label='bottleneck bandwidth')


# 创建第二个y轴
# ax2 = ax1.twinx()
# ax2.plot(x2, y2, 'b-', label='sampleBwData')
# ax2.set_ylabel('sampleBwData', color='b')
# ax2.tick_params('y', colors='b')

# ax2.axhline(y=12500000, color='r', linestyle='--', label='bottleneck bandwidth')

lines1, labels1 = ax1.get_legend_handles_labels()
# lines2, labels2 = ax2.get_legend_handles_labels()
# lines = lines1 + lines2
# labels = labels1 + labels2
ax1.legend(lines1, labels1, loc='upper left')

plt.show()

# %%
path = "/home/ybxiao/test.txt"
startTime = -1
pacingGainData = []
resendData = []
bwData = []
sampleBwData = []

with open(path, 'r') as f:
    for line in f.readlines():
        if(line[0:3] == "re:"):
            cols = line[3:].split(',') 
            t = float(cols[0])
            resent = float(cols[1])
            bw = float(cols[2])
            if(startTime == -1):
                startTime = t
            t = t - startTime
            resendData.append([t, resent])
            bwData.append([t, bw])

        else:
            cols = line[3:].split(',')
            t = float(cols[0])
            sample = float(cols[3])
            if(startTime == -1):
                startTime = t
            t = t - startTime
            sampleBwData.append([t, sample])
    
       
resendData = [row for row in resendData if  10000 <= row[0] and row[0] <= 16000]
sampleBwData = [row for row in sampleBwData if 10000 <= row[0] and row[0] <= 16000]


x1 = [row[0] for row in resendData]

# 提取第二列作为第一条线的纵坐标
y1 = [row[1] for row in resendData]

x2 = [row[0] for row in sampleBwData]
# 提取第二列作为第二条线的纵坐标
y2 = [row[1] for row in sampleBwData]

# 创建画布
fig, ax1 = plt.subplots(figsize=(10, 5))

ax1.plot(x1, y1, 'g-', label='resendData')
ax1.set_xlabel('Time (s)')
ax1.set_ylabel('resendData', color='g')
ax1.tick_params('y', colors='g')

# 创建第二个y轴
ax2 = ax1.twinx()
ax2.plot(x2, y2, 'b-', label='sampleBwData')
ax2.set_ylabel('sampleBwData', color='b')
ax2.tick_params('y', colors='b')

ax2.axhline(y=12500000, color='r', linestyle='--', label='bottleneck bandwidth')

lines1, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
lines = lines1 + lines2
labels = labels1 + labels2
ax1.legend(lines, labels, loc='upper left')

plt.show()

# %%
drop_packets_bbr = [532, 1761, 238]
